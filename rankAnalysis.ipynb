# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("data/rank.csv",sep='\t', engine='python')

# %%
data.head()
# Out:
#    click   os  newuser  ifbrowsed  user_pv_total  user_pv_1  user_pv_2  \
# 0      0  IOS        1          0              0          0          0
# 1      0  IOS        1          0              0          0          0
# 2      0  IOS        1          0              0          0          0
# 3      0  IOS        1          0              0          0          0
# 4      0  IOS        1          0              0          0          0
#
#    user_pv_3  user_pv_4  user_pv_5     ...       user_locprovince  \
# 0          0          0          0     ...                     江苏
# 1          0          0          0     ...                     江苏
# 2          0          0          0     ...                     江苏
# 3          0          0          0     ...                     江苏
# 4          0          0          0     ...                     江苏
#
#    user_locregion  user_loccountry  poi_locprovince  poi_locregion  \
# 0            华东大区               中国               安徽           华东大区
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 282051 entries, 0 to 282050
# Data columns (total 46 columns):
# click               282051 non-null int64
# os                  282051 non-null object
# newuser             282051 non-null int64
# ifbrowsed           282051 non-null int64
# user_pv_total       282051 non-null int64
# user_pv_1           282051 non-null int64
# user_pv_2           282051 non-null int64
# user_pv_3           282051 non-null int64
# user_pv_4           282051 non-null int64
# user_pv_5           282051 non-null int64
# user_pv_6           282051 non-null int64
# user_pv_7           282051 non-null int64
# featpref_1          282051 non-null float64
# featpref_2          282051 non-null float64
# featpref_3          282051 non-null float64
# featpref_4          282051 non-null float64
# featpref_5          282051 non-null float64
# featpref_6          282051 non-null float64
# featpref_7          282051 non-null float64
# ...
